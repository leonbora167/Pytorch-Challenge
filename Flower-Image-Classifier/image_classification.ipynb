# %%
# google colab does not come with torch installed. And also, in course we are using torch 0.4. 
# so following snippet of code installs the relevant version

from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
import torch

# %%
# we will verify that GPU is enabled for this notebook
# following should print: CUDA is available!  Training on GPU ...
# 
# if it prints otherwise, then you need to enable GPU: 
# from Menu > Runtime > Change Runtime Type > Hardware Accelerator > GPU

import torch
import numpy as np

# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
# we need pillow version of 5.3.0
# we will uninstall the older version first
# !pip uninstall -y Pillow
# install the new one
# !pip install Pillow==5.3.0
# import the new one
import PIL
print(PIL.PILLOW_VERSION)
# this should print 5.3.0. If it doesn't, then restart your runtime:
# Menu > Runtime > Restart Runtime
# Out:
# Uninstalling Pillow-5.3.0:
#   Successfully uninstalled Pillow-5.3.0
# Collecting Pillow==5.3.0
#   Using cached https://files.pythonhosted.org/packages/62/94/5430ebaa83f91cc7a9f687ff5238e26164a779cca2ef9903232268b0a318/Pillow-5.3.0-cp36-cp36m-manylinux1_x86_64.whl
# Installing collected packages: Pillow
# Successfully installed Pillow-5.3.0
# 5.3.0

# %%
# Imports here
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import torchvision.models as models
from PIL import Image
import json
from matplotlib.ticker import FormatStrFormatter

# %% [markdown]
# Load the data
#
# Here you'll use torchvision to load the data (documentation). The data should be included alongside this notebook, otherwise you can download it here. The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's [0.485, 0.456, 0.406] and for the standard deviations [0.229, 0.224, 0.225], calculated from the ImageNet images. These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
# we will download the required data files
# !wget -cq https://github.com/udacity/pytorch_challenge/raw/master/cat_to_name.json
# !wget -cq https://s3.amazonaws.com/content.udacity-data.com/courses/nd188/flower_data.zip
# !rm -r flower_data || true
# !unzip -qq flower_data.zip

# %%
data_dir = 'flower_data'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406], 
                                                            [0.229, 0.224, 0.225])])


validation_transforms = transforms.Compose([transforms.Resize(256),
                                            transforms.CenterCrop(224),
                                            transforms.ToTensor(),
                                            transforms.Normalize([0.485, 0.456, 0.406], 
                                                                 [0.229, 0.224, 0.225])])


# TODO: Load the datasets with ImageFolder
train_data = datasets.ImageFolder(train_dir, transform=train_transforms)
validation_data = datasets.ImageFolder(valid_dir, transform=validation_transforms)


# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True)
vloader = torch.utils.data.DataLoader(validation_data, batch_size =32,shuffle = True)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
structures = {"vgg16":25088,
              "densenet121" : 1024,
              "alexnet" : 9216 }

# %%
def nn_setup(structure='vgg16',dropout=0.5, hidden_layer1 = 120,lr = 0.001):
    
    
    if structure == 'vgg16':
        model = models.vgg16(pretrained=True)        
    elif structure == 'densenet121':
        model = models.densenet121(pretrained=True)
    elif structure == 'alexnet':
        model = models.alexnet(pretrained = True)
    else:
        print("Im sorry but {} is not a valid model.Did you mean vgg16,densenet121,or alexnet?".format(structure))
        
    
        
    for param in model.parameters():
        param.requires_grad = False

        from collections import OrderedDict
        classifier = nn.Sequential(OrderedDict([
            ('dropout',nn.Dropout(dropout)),
            ('inputs', nn.Linear(structures[structure], hidden_layer1)),
            ('relu1', nn.ReLU()),
            ('hidden_layer1', nn.Linear(hidden_layer1, 90)),
            ('relu2',nn.ReLU()),
            ('hidden_layer2',nn.Linear(90,80)),
            ('relu3',nn.ReLU()),
            ('hidden_layer3',nn.Linear(80,102)),
            ('output', nn.LogSoftmax(dim=1))
                          ]))
        
        
        model.classifier = classifier
        criterion = nn.NLLLoss()
        optimizer = optim.Adam(model.classifier.parameters(), lr )
        model.cuda()
        
        return model , optimizer ,criterion 

    

model,optimizer,criterion = nn_setup('densenet121')
# Out:
# /usr/local/lib/python3.6/dist-packages/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)

# %%
# Putting the above into functions, so they can be used later

epochs = 12
print_every = 5
steps = 0
loss_show=[]

# change to cuda
model.to('cuda')

for e in range(epochs):
    running_loss = 0
    for ii, (inputs, labels) in enumerate(trainloader):
        steps += 1
        
        inputs,labels = inputs.to('cuda'), labels.to('cuda')
        
        optimizer.zero_grad()
        
        # Forward and backward passes
        outputs = model.forward(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
        if steps % print_every == 0:
            model.eval()
            vlost = 0
            accuracy=0
            
            
            for ii, (inputs2,labels2) in enumerate(vloader):
                optimizer.zero_grad()
                
                inputs2, labels2 = inputs2.to('cuda:0') , labels2.to('cuda:0')
                model.to('cuda:0')
                with torch.no_grad():    
                    outputs = model.forward(inputs2)
                    vlost = criterion(outputs,labels2)
                    ps = torch.exp(outputs).data
                    equality = (labels2.data == ps.max(1)[1])
                    accuracy += equality.type_as(torch.FloatTensor()).mean()
                    
            vlost = vlost / len(vloader)
            accuracy = accuracy /len(vloader)
            
                    
            
            print("Epoch: {}/{}... ".format(e+1, epochs),
                  "Loss: {:.4f}".format(running_loss/print_every),
                  "Validation Lost {:.4f}".format(vlost),
                   "Accuracy: {:.4f}".format(accuracy))
            
            
            running_loss = 0
# Out:
# Epoch: 1/12...  Loss: 4.6229 Validation Lost 0.1783 Accuracy: 0.0192
# Epoch: 1/12...  Loss: 4.6238 Validation Lost 0.1776 Accuracy: 0.0228
# Epoch: 1/12...  Loss: 4.5819 Validation Lost 0.1738 Accuracy: 0.0325
# Epoch: 1/12...  Loss: 4.5633 Validation Lost 0.1709 Accuracy: 0.0262
# Epoch: 1/12...  Loss: 4.5599 Validation Lost 0.1738 Accuracy: 0.0252
# Epoch: 1/12...  Loss: 4.5272 Validation Lost 0.1682 Accuracy: 0.0397
# Epoch: 1/12...  Loss: 4.4705 Validation Lost 0.1660 Accuracy: 0.0252
# Epoch: 1/12...  Loss: 4.3992 Validation Lost 0.1623 Accuracy: 0.0252
# Epoch: 1/12...  Loss: 4.4276 Validation Lost 0.1688 Accuracy: 0.0252
# Epoch: 1/12...  Loss: 4.3535 Validation Lost 0.1627 Accuracy: 0.0911
# Epoch: 1/12...  Loss: 4.3241 Validation Lost 0.1665 Accuracy: 0.1257
# Epoch: 1/12...  Loss: 4.2318 Validation Lost 0.1598 Accuracy: 0.1293
# Epoch: 1/12...  Loss: 4.1020 Validation Lost 0.1533 Accuracy: 0.1329
# Epoch: 1/12...  Loss: 3.9972 Validation Lost 0.1566 Accuracy: 0.1603
# Epoch: 1/12...  Loss: 3.9471 Validation Lost 0.1264 Accuracy: 0.1470
# Epoch: 1/12...  Loss: 3.7508 Validation Lost 0.1381 Accuracy: 0.1790
# Epoch: 1/12...  Loss: 3.7275 Validation Lost 0.1289 Accuracy: 0.1807
# Epoch: 1/12...  Loss: 3.5055 Validation Lost 0.1372 Accuracy: 0.2047
# Epoch: 1/12...  Loss: 3.3145 Validation Lost 0.1290 Accuracy: 0.1870
# Epoch: 1/12...  Loss: 3.3331 Validation Lost 0.1124 Accuracy: 0.2561
# Epoch: 2/12...  Loss: 1.2428 Validation Lost 0.1062 Accuracy: 0.2991
# Epoch: 2/12...  Loss: 2.9043 Validation Lost 0.1146 Accuracy: 0.3025
# Epoch: 2/12...  Loss: 2.8742 Validation Lost 0.1220 Accuracy: 0.3129
# Epoch: 2/12...  Loss: 2.7912 Validation Lost 0.0801 Accuracy: 0.3218
# Epoch: 2/12...  Loss: 2.5368 Validation Lost 0.0957 Accuracy: 0.3515
# Epoch: 2/12...  Loss: 2.5623 Validation Lost 0.0983 Accuracy: 0.3657
# Epoch: 2/12...  Loss: 2.5074 Validation Lost 0.0983 Accuracy: 0.3737
# Epoch: 2/12...  Loss: 2.5514 Validation Lost 0.1017 Accuracy: 0.3992
# Epoch: 2/12...  Loss: 2.5450 Validation Lost 0.0772 Accuracy: 0.4257
# Epoch: 2/12...  Loss: 2.3558 Validation Lost 0.0739 Accuracy: 0.4282
# Epoch: 2/12...  Loss: 2.2458 Validation Lost 0.0743 Accuracy: 0.4275
# Epoch: 2/12...  Loss: 2.4396 Validation Lost 0.0797 Accuracy: 0.3936
# Epoch: 2/12...  Loss: 2.3372 Validation Lost 0.1025 Accuracy: 0.4702
# Epoch: 2/12...  Loss: 2.0117 Validation Lost 0.0696 Accuracy: 0.4798
# Epoch: 2/12...  Loss: 2.2106 Validation Lost 0.0817 Accuracy: 0.4714
# Epoch: 2/12...  Loss: 2.0587 Validation Lost 0.0782 Accuracy: 0.5072
# Epoch: 2/12...  Loss: 2.1315 Validation Lost 0.0727 Accuracy: 0.4748
# Epoch: 2/12...  Loss: 2.0849 Validation Lost 0.0666 Accuracy: 0.4913
# Epoch: 2/12...  Loss: 1.9903 Validation Lost 0.0706 Accuracy: 0.5325
# Epoch: 2/12...  Loss: 1.9569 Validation Lost 0.0634 Accuracy: 0.5132
# Epoch: 2/12...  Loss: 1.6944 Validation Lost 0.0536 Accuracy: 0.5295
# Epoch: 3/12...  Loss: 1.3775 Validation Lost 0.0650 Accuracy: 0.5274
# Epoch: 3/12...  Loss: 1.9081 Validation Lost 0.0840 Accuracy: 0.4936
# Epoch: 3/12...  Loss: 1.8372 Validation Lost 0.0833 Accuracy: 0.5303
# Epoch: 3/12...  Loss: 1.8380 Validation Lost 0.0611 Accuracy: 0.5649
# Epoch: 3/12...  Loss: 1.7939 Validation Lost 0.0688 Accuracy: 0.5697
# Epoch: 3/12...  Loss: 1.9040 Validation Lost 0.0841 Accuracy: 0.5865
# Epoch: 3/12...  Loss: 1.6738 Validation Lost 0.0702 Accuracy: 0.5646
# Epoch: 3/12...  Loss: 1.6169 Validation Lost 0.0543 Accuracy: 0.5984
# Epoch: 3/12...  Loss: 1.5890 Validation Lost 0.0371 Accuracy: 0.5915
# Epoch: 3/12...  Loss: 1.6360 Validation Lost 0.0562 Accuracy: 0.5351
# Epoch: 3/12...  Loss: 1.7174 Validation Lost 0.0597 Accuracy: 0.5700
# Epoch: 3/12...  Loss: 1.5315 Validation Lost 0.0408 Accuracy: 0.5990
# Epoch: 3/12...  Loss: 1.6112 Validation Lost 0.0407 Accuracy: 0.5722
# Epoch: 3/12...  Loss: 1.6050 Validation Lost 0.0643 Accuracy: 0.5979
# Epoch: 3/12...  Loss: 1.6598 Validation Lost 0.0592 Accuracy: 0.5986
# Epoch: 3/12...  Loss: 1.7300 Validation Lost 0.0639 Accuracy: 0.5938
# Epoch: 3/12...  Loss: 1.6319 Validation Lost 0.0415 Accuracy: 0.6064
# Epoch: 3/12...  Loss: 1.5018 Validation Lost 0.0402 Accuracy: 0.6043
# Epoch: 3/12...  Loss: 1.4988 Validation Lost 0.0544 Accuracy: 0.6422
# Epoch: 3/12...  Loss: 1.5065 Validation Lost 0.0640 Accuracy: 0.6418
# Epoch: 4/12...  Loss: 0.2697 Validation Lost 0.0432 Accuracy: 0.6554
# Epoch: 4/12...  Loss: 1.4052 Validation Lost 0.0460 Accuracy: 0.6516
# Epoch: 4/12...  Loss: 1.4373 Validation Lost 0.0605 Accuracy: 0.6149
# Epoch: 4/12...  Loss: 1.4234 Validation Lost 0.0566 Accuracy: 0.6410
# Epoch: 4/12...  Loss: 1.2499 Validation Lost 0.0522 Accuracy: 0.6452
# Epoch: 4/12...  Loss: 1.5095 Validation Lost 0.0638 Accuracy: 0.6437
# Epoch: 4/12...  Loss: 1.3329 Validation Lost 0.0491 Accuracy: 0.6337
# Epoch: 4/12...  Loss: 1.4699 Validation Lost 0.0462 Accuracy: 0.6434
# Epoch: 4/12...  Loss: 1.4361 Validation Lost 0.0313 Accuracy: 0.6588
# Epoch: 4/12...  Loss: 1.2977 Validation Lost 0.0319 Accuracy: 0.6585
# Epoch: 4/12...  Loss: 1.3341 Validation Lost 0.0216 Accuracy: 0.6703
# Epoch: 4/12...  Loss: 1.2987 Validation Lost 0.0408 Accuracy: 0.6492
# Epoch: 4/12...  Loss: 1.3305 Validation Lost 0.0554 Accuracy: 0.6983
# Epoch: 4/12...  Loss: 1.0293 Validation Lost 0.0373 Accuracy: 0.6763
# Epoch: 4/12...  Loss: 1.4505 Validation Lost 0.0425 Accuracy: 0.6540
# Epoch: 4/12...  Loss: 1.2352 Validation Lost 0.0536 Accuracy: 0.6903
# Epoch: 4/12...  Loss: 1.2942 Validation Lost 0.0304 Accuracy: 0.6852
# Epoch: 4/12...  Loss: 1.1489 Validation Lost 0.0408 Accuracy: 0.6737
# Epoch: 4/12...  Loss: 1.2113 Validation Lost 0.0187 Accuracy: 0.6640
# Epoch: 4/12...  Loss: 1.1679 Validation Lost 0.0386 Accuracy: 0.6954
# Epoch: 4/12...  Loss: 1.1162 Validation Lost 0.0543 Accuracy: 0.6972
# Epoch: 5/12...  Loss: 0.6868 Validation Lost 0.0471 Accuracy: 0.6617
# Epoch: 5/12...  Loss: 1.2162 Validation Lost 0.0289 Accuracy: 0.6924
# Epoch: 5/12...  Loss: 1.1798 Validation Lost 0.0668 Accuracy: 0.6656
# Epoch: 5/12...  Loss: 1.2216 Validation Lost 0.0340 Accuracy: 0.6970
# Epoch: 5/12...  Loss: 1.1236 Validation Lost 0.0361 Accuracy: 0.7074
# Epoch: 5/12...  Loss: 1.1489 Validation Lost 0.0256 Accuracy: 0.6960
# Epoch: 5/12...  Loss: 1.1925 Validation Lost 0.0510 Accuracy: 0.7105
# Epoch: 5/12...  Loss: 1.1190 Validation Lost 0.0563 Accuracy: 0.7134
# Epoch: 5/12...  Loss: 1.1884 Validation Lost 0.0394 Accuracy: 0.7105
# Epoch: 5/12...  Loss: 1.1707 Validation Lost 0.0210 Accuracy: 0.6955
# Epoch: 5/12...  Loss: 1.0150 Validation Lost 0.0403 Accuracy: 0.6981
# Epoch: 5/12...  Loss: 1.2688 Validation Lost 0.0466 Accuracy: 0.7006
# Epoch: 5/12...  Loss: 1.0712 Validation Lost 0.0412 Accuracy: 0.6946
# Epoch: 5/12...  Loss: 1.1525 Validation Lost 0.0362 Accuracy: 0.7150
# Epoch: 5/12...  Loss: 1.1312 Validation Lost 0.0385 Accuracy: 0.7105
# Epoch: 5/12...  Loss: 1.2551 Validation Lost 0.0466 Accuracy: 0.6882
# Epoch: 5/12...  Loss: 1.1499 Validation Lost 0.0307 Accuracy: 0.7146
# Epoch: 5/12...  Loss: 1.1177 Validation Lost 0.0275 Accuracy: 0.6919
# Epoch: 5/12...  Loss: 1.1743 Validation Lost 0.0403 Accuracy: 0.7117
# Epoch: 5/12...  Loss: 1.0723 Validation Lost 0.0357 Accuracy: 0.7348
# Epoch: 5/12...  Loss: 1.0678 Validation Lost 0.0398 Accuracy: 0.7254
# Epoch: 6/12...  Loss: 1.1515 Validation Lost 0.0228 Accuracy: 0.7162
# Epoch: 6/12...  Loss: 1.0007 Validation Lost 0.0293 Accuracy: 0.7201
# Epoch: 6/12...  Loss: 1.0636 Validation Lost 0.0469 Accuracy: 0.7254
# Epoch: 6/12...  Loss: 1.0376 Validation Lost 0.0238 Accuracy: 0.7183
# Epoch: 6/12...  Loss: 1.0431 Validation Lost 0.0294 Accuracy: 0.7345
# Epoch: 6/12...  Loss: 1.1300 Validation Lost 0.0537 Accuracy: 0.7368
# Epoch: 6/12...  Loss: 0.9151 Validation Lost 0.0358 Accuracy: 0.7090
# Epoch: 6/12...  Loss: 1.0382 Validation Lost 0.0352 Accuracy: 0.7381
# Epoch: 6/12...  Loss: 0.9169 Validation Lost 0.0474 Accuracy: 0.7269
# Epoch: 6/12...  Loss: 1.0372 Validation Lost 0.0232 Accuracy: 0.7655
# Epoch: 6/12...  Loss: 0.9873 Validation Lost 0.0295 Accuracy: 0.7472
# Epoch: 6/12...  Loss: 1.0472 Validation Lost 0.0211 Accuracy: 0.7373
# Epoch: 6/12...  Loss: 0.9240 Validation Lost 0.0606 Accuracy: 0.7564
# Epoch: 6/12...  Loss: 0.9568 Validation Lost 0.0428 Accuracy: 0.7540
# Epoch: 6/12...  Loss: 1.1168 Validation Lost 0.0165 Accuracy: 0.7553
# Epoch: 6/12...  Loss: 0.9069 Validation Lost 0.0231 Accuracy: 0.7499
# Epoch: 6/12...  Loss: 0.9782 Validation Lost 0.0423 Accuracy: 0.7634
# Epoch: 6/12...  Loss: 1.1667 Validation Lost 0.0533 Accuracy: 0.7778
# Epoch: 6/12...  Loss: 0.8617 Validation Lost 0.0465 Accuracy: 0.7585
# Epoch: 6/12...  Loss: 1.0191 Validation Lost 0.0158 Accuracy: 0.7337
# Epoch: 7/12...  Loss: 0.2800 Validation Lost 0.0242 Accuracy: 0.7508
# Epoch: 7/12...  Loss: 0.8914 Validation Lost 0.0270 Accuracy: 0.7129
# Epoch: 7/12...  Loss: 1.0745 Validation Lost 0.0373 Accuracy: 0.7374
# Epoch: 7/12...  Loss: 0.9948 Validation Lost 0.0182 Accuracy: 0.7508
# Epoch: 7/12...  Loss: 0.9594 Validation Lost 0.0212 Accuracy: 0.7475
# Epoch: 7/12...  Loss: 0.8455 Validation Lost 0.0418 Accuracy: 0.7492
# Epoch: 7/12...  Loss: 0.9860 Validation Lost 0.0384 Accuracy: 0.7634
# Epoch: 7/12...  Loss: 1.0984 Validation Lost 0.0351 Accuracy: 0.7489
# Epoch: 7/12...  Loss: 1.0789 Validation Lost 0.0083 Accuracy: 0.7551
# Epoch: 7/12...  Loss: 0.8995 Validation Lost 0.0281 Accuracy: 0.7597
# Epoch: 7/12...  Loss: 0.8183 Validation Lost 0.0271 Accuracy: 0.7622
# Epoch: 7/12...  Loss: 0.7693 Validation Lost 0.0332 Accuracy: 0.7718
# Epoch: 7/12...  Loss: 0.9186 Validation Lost 0.0355 Accuracy: 0.7751
# Epoch: 7/12...  Loss: 0.9650 Validation Lost 0.0162 Accuracy: 0.7866
# Epoch: 7/12...  Loss: 1.0015 Validation Lost 0.0298 Accuracy: 0.7799
# Epoch: 7/12...  Loss: 0.7518 Validation Lost 0.0231 Accuracy: 0.7520
# Epoch: 7/12...  Loss: 0.8919 Validation Lost 0.0440 Accuracy: 0.7660
# Epoch: 7/12...  Loss: 0.8671 Validation Lost 0.0446 Accuracy: 0.7759
# Epoch: 7/12...  Loss: 1.0645 Validation Lost 0.0497 Accuracy: 0.7684
# Epoch: 7/12...  Loss: 0.8387 Validation Lost 0.0261 Accuracy: 0.7595
# Epoch: 7/12...  Loss: 0.9792 Validation Lost 0.0121 Accuracy: 0.7734
# Epoch: 8/12...  Loss: 0.5635 Validation Lost 0.0297 Accuracy: 0.7672
# Epoch: 8/12...  Loss: 0.9189 Validation Lost 0.0203 Accuracy: 0.7631
# Epoch: 8/12...  Loss: 0.9475 Validation Lost 0.0126 Accuracy: 0.7866
# Epoch: 8/12...  Loss: 0.8709 Validation Lost 0.0355 Accuracy: 0.7814
# Epoch: 8/12...  Loss: 0.9264 Validation Lost 0.0392 Accuracy: 0.7907
# Epoch: 8/12...  Loss: 0.8262 Validation Lost 0.0339 Accuracy: 0.7847
# Epoch: 8/12...  Loss: 0.7709 Validation Lost 0.0244 Accuracy: 0.7691
# Epoch: 8/12...  Loss: 0.8642 Validation Lost 0.0166 Accuracy: 0.7926
# Epoch: 8/12...  Loss: 0.8739 Validation Lost 0.0216 Accuracy: 0.7823
# Epoch: 8/12...  Loss: 0.8187 Validation Lost 0.0191 Accuracy: 0.7782
# Epoch: 8/12...  Loss: 0.8097 Validation Lost 0.0262 Accuracy: 0.7766
# Epoch: 8/12...  Loss: 0.8943 Validation Lost 0.0350 Accuracy: 0.7819
# Epoch: 8/12...  Loss: 0.8487 Validation Lost 0.0489 Accuracy: 0.8081
# Epoch: 8/12...  Loss: 0.8726 Validation Lost 0.0073 Accuracy: 0.7945
# Epoch: 8/12...  Loss: 0.8822 Validation Lost 0.0331 Accuracy: 0.7955
# Epoch: 8/12...  Loss: 0.8562 Validation Lost 0.0183 Accuracy: 0.8061
# Epoch: 8/12...  Loss: 0.7645 Validation Lost 0.0339 Accuracy: 0.7891
# Epoch: 8/12...  Loss: 0.8063 Validation Lost 0.0567 Accuracy: 0.8133
# Epoch: 8/12...  Loss: 0.9037 Validation Lost 0.0370 Accuracy: 0.7953
# Epoch: 8/12...  Loss: 0.7827 Validation Lost 0.0342 Accuracy: 0.7979
# Epoch: 9/12...  Loss: 0.1510 Validation Lost 0.0269 Accuracy: 0.8042
# Epoch: 9/12...  Loss: 0.9863 Validation Lost 0.0224 Accuracy: 0.7953
# Epoch: 9/12...  Loss: 0.8638 Validation Lost 0.0401 Accuracy: 0.7871
# Epoch: 9/12...  Loss: 0.8244 Validation Lost 0.0326 Accuracy: 0.8040
# Epoch: 9/12...  Loss: 0.8153 Validation Lost 0.0370 Accuracy: 0.7859
# Epoch: 9/12...  Loss: 0.8498 Validation Lost 0.0202 Accuracy: 0.7794
# Epoch: 9/12...  Loss: 0.7664 Validation Lost 0.0293 Accuracy: 0.7934
# Epoch: 9/12...  Loss: 0.7754 Validation Lost 0.0207 Accuracy: 0.7866
# Epoch: 9/12...  Loss: 0.9806 Validation Lost 0.0234 Accuracy: 0.7902
# Epoch: 9/12...  Loss: 0.7302 Validation Lost 0.0117 Accuracy: 0.8022
# Epoch: 9/12...  Loss: 0.7957 Validation Lost 0.0467 Accuracy: 0.8162
# Epoch: 9/12...  Loss: 0.8446 Validation Lost 0.0260 Accuracy: 0.8178
# Epoch: 9/12...  Loss: 0.7610 Validation Lost 0.0383 Accuracy: 0.8172
# Epoch: 9/12...  Loss: 0.8415 Validation Lost 0.0133 Accuracy: 0.8034
# Epoch: 9/12...  Loss: 0.6335 Validation Lost 0.0327 Accuracy: 0.8057
# Epoch: 9/12...  Loss: 0.6604 Validation Lost 0.0197 Accuracy: 0.7989
# Epoch: 9/12...  Loss: 0.8090 Validation Lost 0.0205 Accuracy: 0.8217
# Epoch: 9/12...  Loss: 0.8908 Validation Lost 0.0232 Accuracy: 0.7893
# Epoch: 9/12...  Loss: 0.8017 Validation Lost 0.0211 Accuracy: 0.7835
# Epoch: 9/12...  Loss: 0.7424 Validation Lost 0.0206 Accuracy: 0.8202
# Epoch: 9/12...  Loss: 0.7845 Validation Lost 0.0132 Accuracy: 0.7935
# Epoch: 10/12...  Loss: 0.4235 Validation Lost 0.0380 Accuracy: 0.7636
# Epoch: 10/12...  Loss: 0.7930 Validation Lost 0.0131 Accuracy: 0.7830
# Epoch: 10/12...  Loss: 0.7786 Validation Lost 0.0097 Accuracy: 0.7983
# Epoch: 10/12...  Loss: 0.6931 Validation Lost 0.0333 Accuracy: 0.7967
# Epoch: 10/12...  Loss: 0.6872 Validation Lost 0.0258 Accuracy: 0.8076
# Epoch: 10/12...  Loss: 0.8288 Validation Lost 0.0325 Accuracy: 0.7939
# Epoch: 10/12...  Loss: 0.8764 Validation Lost 0.0128 Accuracy: 0.8169
# Epoch: 10/12...  Loss: 0.7524 Validation Lost 0.0258 Accuracy: 0.8160
# Epoch: 10/12...  Loss: 0.7909 Validation Lost 0.0246 Accuracy: 0.8076
# Epoch: 10/12...  Loss: 0.6714 Validation Lost 0.0177 Accuracy: 0.8044
# Epoch: 10/12...  Loss: 0.7579 Validation Lost 0.0445 Accuracy: 0.8072
# Epoch: 10/12...  Loss: 0.7058 Validation Lost 0.0396 Accuracy: 0.8213
# Epoch: 10/12...  Loss: 0.6985 Validation Lost 0.0164 Accuracy: 0.8289
# Epoch: 10/12...  Loss: 0.7842 Validation Lost 0.0145 Accuracy: 0.8190
# Epoch: 10/12...  Loss: 0.7628 Validation Lost 0.0241 Accuracy: 0.8220
# Epoch: 10/12...  Loss: 0.7447 Validation Lost 0.0124 Accuracy: 0.8299
# Epoch: 10/12...  Loss: 0.7417 Validation Lost 0.0178 Accuracy: 0.8226
# Epoch: 10/12...  Loss: 0.8103 Validation Lost 0.0229 Accuracy: 0.8076
# Epoch: 10/12...  Loss: 0.8219 Validation Lost 0.0241 Accuracy: 0.8241
# Epoch: 10/12...  Loss: 0.7374 Validation Lost 0.0648 Accuracy: 0.8148
# Epoch: 10/12...  Loss: 0.8145 Validation Lost 0.0293 Accuracy: 0.8263
# Epoch: 11/12...  Loss: 0.7351 Validation Lost 0.0290 Accuracy: 0.8247
# Epoch: 11/12...  Loss: 0.7473 Validation Lost 0.0117 Accuracy: 0.8341
# Epoch: 11/12...  Loss: 0.7247 Validation Lost 0.0256 Accuracy: 0.8169
# Epoch: 11/12...  Loss: 0.6850 Validation Lost 0.0220 Accuracy: 0.8325
# Epoch: 11/12...  Loss: 0.8082 Validation Lost 0.0183 Accuracy: 0.8361
# Epoch: 11/12...  Loss: 0.6928 Validation Lost 0.0062 Accuracy: 0.8293
# Epoch: 11/12...  Loss: 0.7235 Validation Lost 0.0265 Accuracy: 0.8232
# Epoch: 11/12...  Loss: 0.7015 Validation Lost 0.0148 Accuracy: 0.8349
# Epoch: 11/12...  Loss: 0.7490 Validation Lost 0.0306 Accuracy: 0.8136
# Epoch: 11/12...  Loss: 0.7174 Validation Lost 0.0172 Accuracy: 0.8347
# Epoch: 11/12...  Loss: 0.8294 Validation Lost 0.0114 Accuracy: 0.8395
# Epoch: 11/12...  Loss: 0.6581 Validation Lost 0.0340 Accuracy: 0.8343
# Epoch: 11/12...  Loss: 0.7717 Validation Lost 0.0203 Accuracy: 0.8172
# Epoch: 11/12...  Loss: 0.8274 Validation Lost 0.0188 Accuracy: 0.8100
# Epoch: 11/12...  Loss: 0.8521 Validation Lost 0.0226 Accuracy: 0.8085
# Epoch: 11/12...  Loss: 0.6400 Validation Lost 0.0073 Accuracy: 0.8161
# Epoch: 11/12...  Loss: 0.7677 Validation Lost 0.0242 Accuracy: 0.8174
# Epoch: 11/12...  Loss: 0.5942 Validation Lost 0.0395 Accuracy: 0.8189
# Epoch: 11/12...  Loss: 0.6587 Validation Lost 0.0329 Accuracy: 0.8084
# Epoch: 11/12...  Loss: 0.6942 Validation Lost 0.0086 Accuracy: 0.8248
# Epoch: 12/12...  Loss: 0.3428 Validation Lost 0.0739 Accuracy: 0.8424
# Epoch: 12/12...  Loss: 0.6245 Validation Lost 0.0071 Accuracy: 0.8380
# Epoch: 12/12...  Loss: 0.8346 Validation Lost 0.0346 Accuracy: 0.8379
# Epoch: 12/12...  Loss: 0.5604 Validation Lost 0.0252 Accuracy: 0.8268
# Epoch: 12/12...  Loss: 0.6397 Validation Lost 0.0118 Accuracy: 0.8371
# Epoch: 12/12...  Loss: 0.6938 Validation Lost 0.0146 Accuracy: 0.8251
# Epoch: 12/12...  Loss: 0.6678 Validation Lost 0.0093 Accuracy: 0.8226
# Epoch: 12/12...  Loss: 0.7310 Validation Lost 0.0087 Accuracy: 0.8368
# Epoch: 12/12...  Loss: 0.6674 Validation Lost 0.0137 Accuracy: 0.8347
# Epoch: 12/12...  Loss: 0.7147 Validation Lost 0.0166 Accuracy: 0.8241
# Epoch: 12/12...  Loss: 0.7654 Validation Lost 0.0089 Accuracy: 0.8368
# Epoch: 12/12...  Loss: 0.6979 Validation Lost 0.0240 Accuracy: 0.8337
# Epoch: 12/12...  Loss: 0.6319 Validation Lost 0.0066 Accuracy: 0.8224
# Epoch: 12/12...  Loss: 0.7112 Validation Lost 0.0303 Accuracy: 0.8379
# Epoch: 12/12...  Loss: 0.6694 Validation Lost 0.0209 Accuracy: 0.8421
# Epoch: 12/12...  Loss: 0.6454 Validation Lost 0.0244 Accuracy: 0.8226
# Epoch: 12/12...  Loss: 0.6888 Validation Lost 0.0118 Accuracy: 0.8299
# Epoch: 12/12...  Loss: 0.5753 Validation Lost 0.0196 Accuracy: 0.8352
# Epoch: 12/12...  Loss: 0.6335 Validation Lost 0.0364 Accuracy: 0.8345
# Epoch: 12/12...  Loss: 0.6375 Validation Lost 0.0187 Accuracy: 0.8301
# Epoch: 12/12...  Loss: 0.6822 Validation Lost 0.0115 Accuracy: 0.8476

# %%
# TODO: Save the checkpoint 
model.class_to_idx = train_data.class_to_idx
model.cpu
torch.save({'structure' :'densenet121',
            'hidden_layer1':120,
            'state_dict':model.state_dict(),
            'class_to_idx':model.class_to_idx},
            'checkpoint.pth')

# %%
def load_model(path):
    checkpoint = torch.load('checkpoint.pth')
    structure = checkpoint['structure']
    hidden_layer1 = checkpoint['hidden_layer1']
    model,_,_ = nn_setup(structure , 0.5,hidden_layer1)
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])
    
    
load_model('checkpoint.pth')
# Out:
# /usr/local/lib/python3.6/dist-packages/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)

# %%
def process_image(image):
    img_pil = Image.open(image)
   
    adjustments = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    img_tensor = adjustments(img_pil)
    
    return img_tensor
    
    
    # TODO: Process a PIL image for use in a PyTorch model

img = (data_dir + '/valid' + '/1/' + 'image_06739.jpg')
img = process_image(img)
print(img.shape)
# Out:
# torch.Size([3, 224, 224])

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax


imshow(process_image("flower_data/valid/1/image_06739.jpg"))

# %%
def check_sanity():
    plt.rcParams["figure.figsize"] = (10,5)
    plt.subplot(211)
    
    index = 1
    path = 'flower_data/valid' + '/1/image_06739.jpg'

    probabilities = predict(path, model)
    image = process_image(path)
    probabilities = probabilities
    

    axs = imshow(image, ax = plt)
    axs.axis('off')
    axs.title(cat_to_name[str(index)])
    axs.show()
    
    
    a = np.array(probabilities[0][0])
    b = [cat_to_name[str(index + 1)] for index in np.array(probabilities[1][0])]
    
    
    N=float(len(b))
    fig,ax = plt.subplots(figsize=(8,3))
    width = 0.8
    tickLocations = np.arange(N)
    ax.bar(tickLocations, a, width, linewidth=4.0, align = 'center')
    ax.set_xticks(ticks = tickLocations)
    ax.set_xticklabels(b)
    ax.set_xlim(min(tickLocations)-0.6,max(tickLocations)+0.6)
    ax.set_yticks([0.2,0.4,0.6,0.8,1,1.2])
    ax.set_ylim((0,1))
    ax.yaxis.grid(True)
    ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))

    plt.show()

# %%
model.class_to_idx =train_data.class_to_idx

ctx = model.class_to_idx


def predict(image_path, model, topk=5):   
    model.to('cuda:0')
    img_torch = process_image(image_path)
    img_torch = img_torch.unsqueeze_(0)
    img_torch = img_torch.float()
    
    with torch.no_grad():
        output = model.forward(img_torch.cuda())
        
    probability = F.softmax(output.data,dim=1)
    
    return probability.topk(topk)

# %%
check_sanity()
